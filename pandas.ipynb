# %%
import pandas as pd

# %%
# Series
serie = pd.Series([5,10,15,20,25,30])
type(serie)
print(serie.shape)
p = pd.Series(['C','r','i','s'])
p
# Out:
# (6,)
# 0    C
# 1    r
# 2    i
# 3    s
# dtype: object

# %%
# Dataframe
dataf = pd.DataFrame(['Cris', 'you', 'are', 'the', 'best'])
dataf
data = {
    'Name': ['Cris', 'Cami'],
    'Age': [28, 29],
    'Country': ['Colombia', 'Estonia']
}

df = pd.DataFrame(data)
df['Name']
df[0:]
# Out:
#    Name  Age   Country
# 0  Cris   28  Colombia
# 1  Cami   29   Estonia

# %%
# From file
data = pd.read_csv('canciones-2018.csv')
data.name.head()
data.name
info = data.iloc[15]
# Error -> data[15]
info
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# Aditional info
data['tempo'].describe()
data.sort_index(axis=0, ascending=False)
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...

# %%
data.sort_values(by=['artists','name'], axis=0, ascending=True)
# Out:
#                        id                                    name  \
# 23  2iUXsYOEPhVqEBwsqP70r                              Youngblood
# 55  2E124GmJRnBJuXbTb4cPU  FEFE (feat. Nicki Minaj & Murda Beatz)
# 88  3Ga6eKrUFf12ouh9Yw3v2                                Downtown
# 60  2BgEsaKNfHUdlh97KmvFy                                    2002
# 65  5OCJzvD7sykQEKHH7qAC3                          God is a woman
# ..                    ...                                     ...
# 38  7AFASza1mXqntmGtbxXpr                                 changes
# 98  1j4kHkkpqZRBwE0A4CN4Y             Dusk Till Dawn - Radio Edit
# 95  630sXRhIcfwr2e4RdNtjK                       Rewrite The Stars
# 14  09IStsImFySgyp0pIQdqA                              The Middle
# 35  0d2iYfpKoM0QCKvcLCkBa         Eastside (with Halsey & Khalid)
#
#                 artists  danceability  energy   key  loudness  mode  \
# 23  5 Seconds of Summer         0.596   0.854   7.0    -5.114   0.0
# ...
